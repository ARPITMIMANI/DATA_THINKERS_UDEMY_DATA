# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv ( "UDEMY_DATA.csv" , parse_dates=["published_timestamp"] )
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
# GET THE DATA TYPES OF COLUMNS FROM THE DATA SET .

df.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
# GET TOP 10 ROWS OF THE DATA SET .

df.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %%
# GET BOTTOM 10 ROWS OF THE DATA SET .

df.tail(10)
# Out:
#       course_id                                       course_title  \
# 3668     270976                             A how to guide in HTML
# 3669     679992                  Building Better APIs with GraphQL
# 3670     330900  Learn Grunt with Examples: Automate Your Front...
# 3671     667122  Build A Stock Downloader With Visual Studio 20...
# 3672     865438    jQuery UI in Action: Build 5 jQuery UI Projects
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3668      https://www.udemy.com/a-how-to-guide-in-html/    False      0
# 3669  https://www.udemy.com/building-better-apis-wit...     True     50
# ...

# %%
# GET THE SHAPE OF THE DATA SET .

df.shape
# Out:
# (3678, 12)

# %%
# GET THE NUMBER OF ROWS FROM THE DATA SET .

df.shape[0]
# Out:
# 3678

# %%
# GET THE NUMBER OF COLUMNS FROM THE DATA SET .

df.shape[1]
# Out:
# 12

# %%
# GET THE INFORMATION OF THE DATA SET .

print ( "THE INFORMATION OF THE DATA SET IS GIVEN ABOVE" , df.info() )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB
# THE INFORMATION OF THE DATA SET IS GIVEN ABOVE None

# %%
# CHECK THE NULL VALUES FROM THE DATA SET .

df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %%
sns.heatmap ( data = df.isnull() )
# Out:
# <Axes: >

# %%
# CHECK FOR ANY DUPLICATE DATA AND DROP THEM .

df.duplicated().any()
# Out:
# True

# %%
df = df.drop_duplicates()
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
df.duplicated().any()
# Out:
# False

# %%
df.shape
# Out:
# (3672, 12)

# %%
# GET THE LIST OF COLUMNS FROM THE DATA SET .

df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# FIND THE NUMBERS OF COURSES PER SUBJECT .

df.groupby ("subject") ["course_title"].count()
# Out:
# subject
# Business Finance       1191
# Graphic Design          602
# Musical Instruments     680
# Web Development        1199
# Name: course_title, dtype: int64

# %%
df["subject"]. value_counts()
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# FOR WHICH LEVELS UDEMY ARE PROVIDING THE COURSES .

df["level"]. value_counts()
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# DISPLAY THE COUNT OF FREE AND PAID COURSES .

df["is_paid"]. value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# WHICH COURSE ( FREE OR PAID ) HAS MORE LECTURES .

df.groupby ("is_paid") ["num_lectures"] .sum()#
# Out:
# is_paid
# False      6639
# True     140756
# Name: num_lectures, dtype: int64

# %%
df.groupby ("is_paid") .sum()
# Out:
# C:\Users\ARPIT-MIMANI\AppData\Local\Temp\ipykernel_9288\2688350096.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby ("is_paid") .sum()
#           course_id   price  num_subscribers  num_reviews  num_lectures  \
# is_paid
# False     214348561       0          3575525       132038          6639
# True     2267547787  242730          8140310       442158        140756
#
#          content_duration
# is_paid
# False          685.333333
# True         14361.066667

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# WHICH COURSE ( FREE OR PAID ) HAS HIGHER NUMBER OF SUBSCRIBERS .

df.groupby ("is_paid") ["num_subscribers"] .sum()
# Out:
# is_paid
# False    3575525
# True     8140310
# Name: num_subscribers, dtype: int64

# %%
sns.barplot ( x="is_paid" , y="num_subscribers" , data=df )
plt.xlabel ( "PAID COURSE" , fontsize=12 )
plt.ylabel ( "NUMBER OF SUBSCRIBERS" , fontsize=12 )
plt.title ( "NUMBERS OF SUBSCRIBERS PER COURSE" , fontsize=16 )
plt.xticks ( rotation=0 )
# Out:
# (array([0, 1]), [Text(0, 0, 'False'), Text(1, 0, 'True')])

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# WHICH LELVEL HAS HIGHEST NUMBER OF SUBSCRIBERS .

df.groupby ("level") ["num_subscribers"] .sum()
# Out:
# level
# All Levels            6871791
# Beginner Level        4051843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
sns.barplot ( x="level" , y="num_subscribers" , data=df )
plt.xlabel ( "LEVELS" , fontsize=12 )
plt.ylabel ( "NUMBER OF SUBSCRIBERS" , fontsize=12 )
plt.title ( "NUMBERS OF SUBSCRIBERS PER LEVEL" , fontsize=16 )
plt.xticks ( rotation=30 )
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'All Levels'),
#   Text(1, 0, 'Intermediate Level'),
#   Text(2, 0, 'Beginner Level'),
#   Text(3, 0, 'Expert Level')])

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# FIND MOST POPULAR COURSE TITLE AS PER NUMBER OF SUBSCRIBERS .

df["num_subscribers"].max()
# Out:
# 268923

# %%
df [ df["num_subscribers"] == df["num_subscribers"].max() ]
# Out:
#       course_id                          course_title  \
# 2827      41295  Learn HTML5 Programming From Scratch
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 2827           268923         8629            45  All Levels
#
#       content_duration       published_timestamp          subject
# 2827              10.5 2013-02-14 07:03:41+00:00  Web Development

# %%
df [ df["num_subscribers"] == df["num_subscribers"].max() ] ["course_title"]
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# DISPLAY 10 MOST POPULAR COURSES AS PER NUMBER OF SUBSCRIBERS .

df["num_subscribers"]. sort_values ( ascending=False )
# Out:
# 2827    268923
# 3032    161029
# 3230    121584
# 2783    120291
# 3232    114512
#          ...
# 1234         0
# 886          0
# 887          0
# 888          0
# 777          0
# Name: num_subscribers, Length: 3672, dtype: int64

# %%
df["num_subscribers"]. sort_values ( ascending=False ) .head(10)
# Out:
# 2827    268923
# 3032    161029
# 3230    121584
# 2783    120291
# 3232    114512
# 1896    101154
# 2589     98867
# 2619     84897
# 3289     83737
# 3247     79612
# Name: num_subscribers, dtype: int64

# %%
df.sort_values ( by="num_subscribers", ascending=False )
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# ...         ...                                                ...
# 1234     185526                             MicroStation - Células
# 886     1087466  Stop Creditors from Harassing you and Avoid Ba...
# 887     1058852            Learn to trade using technical analysis
# 888     1083744  How to Invest Using ETFs from Former Wall Stre...
# 777     1215926                Kickstarter success in 5 easy steps
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# ...

# %%
df.sort_values ( by="num_subscribers", ascending=False ) .head(10)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# 1896      19421              Free Beginner Electric Guitar Lessons
# 2589     473160  Web Design for Web Developers: Build Beautiful...
# 2619      94430             Learn Javascript & JQuery From Scratch
# 3289     130064  Practical PHP: Master the Basics and Code Dyna...
# 3247     364426          JavaScript: Understanding the Weird Parts
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# ...

# %%
newdf = df.sort_values ( by="num_subscribers", ascending=False ) .head(10)
newdf
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# 1896      19421              Free Beginner Electric Guitar Lessons
# 2589     473160  Web Design for Web Developers: Build Beautiful...
# 2619      94430             Learn Javascript & JQuery From Scratch
# 3289     130064  Practical PHP: Master the Basics and Code Dyna...
# 3247     364426          JavaScript: Understanding the Weird Parts
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# ...

# %%
sns.barplot ( y="course_title" , x="num_subscribers" , data=newdf )
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# FIND THE COURSE WHICH IS HAVING HIGHEST NUMBER OF REVIEWS .

plt.figure ( figsize= (10,4) )
sns.barplot ( x="subject" , y="num_reviews" , data=df )
plt.xlabel ( "SUBJECTS" , fontsize=12 )
plt.ylabel ( "NUMBER OF REVIEWS" , fontsize=12 )
plt.title ( "NUMBERS OF REVIEWS PER SUBJECT" , fontsize=16 )
plt.xticks ( rotation=0 )
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Business Finance'),
#   Text(1, 0, 'Graphic Design'),
#   Text(2, 0, 'Musical Instruments'),
#   Text(3, 0, 'Web Development')])

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# DOES PRICE AFFECT NUMBER OF REVIEWS .

df.groupby("price") ["num_reviews"] .sum()
# Out:
# price
# 0      132038
# 20      27107
# 25       6003
# 30      11505
# 35       3836
# 40       7306
# 45       3704
# 50      26427
# 55       1374
# 60       9244
# 65       2916
# 70       1454
# 75      12490
# 80       4052
# 85       1543
# 90       1302
# 95       9962
# 100     14778
# 105      1213
# 110      5183
# 115      2268
# 120      6874
# 125      2196
# 130        86
# 135       302
# 140      5127
# 145      6533
# 150     29611
# 155       526
# 160       546
# 165      1171
# 170       336
# 175     29616
# 180     16839
# 185      1353
# 190     34075
# 195     52469
# 200    100831
# Name: num_reviews, dtype: int64

# %%
plt.figure ( figsize= (16,6) )
sns.scatterplot ( x="price" , y="num_reviews" , data=df )
plt.xlabel ( "PRICE OF COURSE" , fontsize=12 )
plt.ylabel ( "NUMBER OF REVIEWS" , fontsize=12 )
plt.title ( "NUMBERS OF REVIEWS VS PRICE OF COURSE" , fontsize=16 )
plt.xticks ( rotation=0 )
# Out:
# (array([-25.,   0.,  25.,  50.,  75., 100., 125., 150., 175., 200., 225.]),
#  [Text(-25.0, 0, '−25'),
#   Text(0.0, 0, '0'),
#   Text(25.0, 0, '25'),
#   Text(50.0, 0, '50'),
#   Text(75.0, 0, '75'),
#   Text(100.0, 0, '100'),
#   Text(125.0, 0, '125'),
#   Text(150.0, 0, '150'),
#   Text(175.0, 0, '175'),
#   Text(200.0, 0, '200'),
#   Text(225.0, 0, '225')])

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# FIND THE NUMBER OF COURSES RELATED TO PYTHON .

df["course_title"] .str.contains ( "PYTHON" , case=False )
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3673    False
# 3674    False
# 3675    False
# 3676    False
# 3677    False
# Name: course_title, Length: 3672, dtype: bool

# %%
df [ df["course_title"] .str.contains ( "PYTHON" , case=False ) ]
# Out:
#       course_id                                       course_title  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 147     1070886         Python Algo Trading: FX Trading with Oanda
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
# 2528     391546        Learn Python and Django: Payment Processing
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# ...

# %%
len ( df [ df["course_title"] .str.contains ( "PYTHON" , case=False ) ] )
# Out:
# 29

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# DISPLAY 10 MOST POPULAR PYTHON COURSES AS PER NUMBER OF SUBSCRIBERS .

df [ df["course_title"] .str.contains ( "PYTHON" , case=False ) ] .sort_values ( by="num_subscribers" , ascending=False )
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
# 3392      70640  Python Programming: Create an Digital Marketpl...
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 3160     368340    Professional Python Web Development Using Flask
# ...

# %%
df [ df["course_title"] .str.contains ( "PYTHON" , case=False ) ] \
.sort_values ( by="num_subscribers" , ascending=False ) .head(10)
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
#
#                                                     url  is_paid  price  \
# 2497  https://www.udemy.com/web-programming-with-pyt...     True     50
# 2570    https://www.udemy.com/coding-for-entrepreneurs/     True    195
# ...

# %%
newdf = df [ df["course_title"] .str.contains ( "PYTHON" , case=False ) ] \
.sort_values ( by="num_subscribers" , ascending=False ) .head(10)
newdf
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
#
#                                                     url  is_paid  price  \
# 2497  https://www.udemy.com/web-programming-with-pyt...     True     50
# 2570    https://www.udemy.com/coding-for-entrepreneurs/     True    195
# ...

# %%
sns.barplot ( y="course_title" , x="num_subscribers" , data=newdf )
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# IN WHICH YEAR THE HIGHEST NUMBER OF COURSES WERE POSTED .

df["published_timestamp"]
# Out:
# 0      2017-01-18 20:58:58+00:00
# 1      2017-03-09 16:34:20+00:00
# 2      2016-12-19 19:26:30+00:00
# 3      2017-05-30 20:07:24+00:00
# 4      2016-12-13 14:57:18+00:00
#                   ...
# 3673   2016-06-14 17:36:46+00:00
# 3674   2017-03-10 22:24:30+00:00
# 3675   2015-12-30 16:41:42+00:00
# 3676   2016-08-11 19:06:15+00:00
# 3677   2014-09-28 19:51:11+00:00
# Name: published_timestamp, Length: 3672, dtype: datetime64[ns, UTC]

# %%
df["published_timestamp"]. dt.year
# Out:
# 0       2017
# 1       2017
# 2       2016
# 3       2017
# 4       2016
#         ...
# 3673    2016
# 3674    2017
# 3675    2015
# 3676    2016
# 3677    2014
# Name: published_timestamp, Length: 3672, dtype: int64

# %%
df["year_number"] = df["published_timestamp"]. dt.year
df["year_number"]
# Out:
# C:\Users\ARPIT-MIMANI\AppData\Local\Temp\ipykernel_9288\13365224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["year_number"] = df["published_timestamp"]. dt.year
# 0       2017
# 1       2017
# 2       2016
# 3       2017
# 4       2016
#         ...
# 3673    2016
# 3674    2017
# 3675    2015
# 3676    2016
# 3677    2014
# Name: year_number, Length: 3672, dtype: int64

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'year_number'],
#       dtype='object')

# %%
df.groupby ("year_number") ["year_number"] .count()
# Out:
# year_number
# 2011       5
# 2012      45
# 2013     201
# 2014     490
# 2015    1014
# 2016    1204
# 2017     713
# Name: year_number, dtype: int64

# %%
df["year_number"]. value_counts()
# Out:
# 2016    1204
# 2015    1014
# 2017     713
# 2014     490
# 2013     201
# 2012      45
# 2011       5
# Name: year_number, dtype: int64

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'year_number'],
#       dtype='object')

# %%
# DISPLAY CATEGORY WISE COUNT OF POSTED SUBJECTS [ YEAR WISE ] .

df.groupby ("year_number") ["subject"] .value_counts()
# Out:
# year_number  subject
# 2011         Web Development          5
# 2012         Web Development         19
#              Graphic Design          10
#              Musical Instruments     10
#              Business Finance         6
# 2013         Business Finance        84
#              Web Development         55
#              Musical Instruments     39
#              Graphic Design          23
# 2014         Business Finance       192
#              Musical Instruments    120
#              Web Development        113
#              Graphic Design          65
# 2015         Business Finance       339
#              Web Development        336
#              Musical Instruments    171
#              Graphic Design         168
# 2016         Web Development        448
#              Business Finance       347
#              Musical Instruments    228
#              Graphic Design         181
# 2017         Business Finance       223
#              Web Development        223
# ...

# %%
# DISPLAY RANDOM NUMBER OF ROWS FROM THE DATA SET .

df.sample(16)
# Out:
#       course_id                                       course_title  \
# 1002     322332                         Learn To Invest In 7 Steps
# 3560     149042                  JavaScript for Absolute Beginners
# 2065      51752  Just chords Piano: Learn to Play Piano Quickly...
# 1379     406424  Photoshop, Illustrator, InDesign & Graphic Des...
# 586     1246684  Dash Crypto Currency Technical and Trading Ove...
# 1711     792232                 Most Wanted Flat Design Techniques
# 435      587232  Simple Linear Regression Analysis ( A Complete...
# 3471     552258  Professional WordPress Theme Development from ...
# 1790     335902                                 eBook Cover Design
# 2335     139772  How to play easy tunes on the harmonica - just...
# 2834     188692  Build a Responsive Website with a Modern Flat ...
# 872     1169188  Energiespar-Formel // Mehr Geld durch Wasser s...
# 2949     862478  Build Your Startup with No Coding (Design, Dev...
# ...
